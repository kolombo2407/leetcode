# %%
x = 1221

# %% [markdown]
# ### my solution

# %%
def isPalindrome(x: int) -> bool:
    x_s = str(x)
    
    if len(x_s)%2 == 0:
        start = x_s[:int(len(x_s)/2)]
        end = x_s[int(len(x_s)/2):]
        if start == end[::-1]:
            return True
    elif len(x_s)%2 != 0:
        start = x_s[:int(len(x_s)/2)+1]
        end = x_s[int(len(x_s)/2):]
        if start == end[::-1]:
            return True
    return False

# %%
isPalindrome(x)
# Out:
# True
